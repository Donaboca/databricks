# %% [markdown]
# # Edellisen viikon junatiedot

# %%
import requests
from requests.exceptions import HTTPError
import pandas as pd
import datetime as dt

today = dt.date.today()
first_day_of_current_week = today - dt.timedelta(days=today.weekday())
first_day_of_previous_week = first_day_of_current_week - dt.timedelta(weeks=1)
last_day_of_previous_week = first_day_of_current_week - dt.timedelta(days=1)


base_api_url = 'https://rata.digitraffic.fi/api/v1/trains/'
json_list = []

try:
    for date in pd.date_range(first_day_of_previous_week, last_day_of_previous_week):
        response = requests.get(base_api_url + date.strftime('%Y-%m-%d'))
        response.raise_for_status()
        trains_json = response.json()
        if isinstance(trains_json, list):
            json_list.extend(trains_json)
        else:
            json_list.append(trains_json)
    print(f'Data noudettu onnistuneesti {first_day_of_previous_week.strftime('%d.%m.%Y')} - {last_day_of_previous_week.strftime('%d.%m.%Y')} väliseltä ajalta.')
except HTTPError as http_err:
    print(f'Datan noutamisessa tapahtui virhe: {http_err}')
except Exception as err:
    print(f'Tapahtui odottamaton virhe: {err}')
# Out:
# Data noudettu onnistuneesti 19.01.2026 - 25.01.2026 väliseltä ajalta.

# %%
json_list

# %%
trains = pd.json_normalize(json_list,
                           record_path=['timeTableRows'],
                           meta=[
                              'trainNumber', 
                              'departureDate', 
                              'operatorUICCode',
                              'operatorShortCode',
                              'trainType',
                              'trainCategory',
                              'commuterLineID'
                           ]
)

trains = trains.drop(columns = ['stationUICCode', 'countryCode', 'stopSector', 'commercialTrack', 'trainReady.source', 'trainReady.accepted', 'trainReady.timestamp',
                                'trainStopping', 'commercialStop', 'estimateSource', 'liveEstimateTime', 'unknownTrack', 'unknownDelay', 'causes'])

trains.head()
# Out:
#   stationShortCode       type  cancelled             scheduledTime  \
# 0              HKI  DEPARTURE      False  2026-01-19T04:54:00.000Z
# 1              PSL    ARRIVAL      False  2026-01-19T04:59:00.000Z
# 2              PSL  DEPARTURE      False  2026-01-19T05:00:00.000Z
# 3              LOP    ARRIVAL      False  2026-01-19T05:00:53.000Z
# 4              LOP  DEPARTURE      False  2026-01-19T05:00:53.000Z
#
#                  actualTime  differenceInMinutes trainNumber departureDate  \
# 0  2026-01-19T04:54:31.000Z                  1.0           1    2026-01-19
# 1  2026-01-19T04:59:11.000Z                  0.0           1    2026-01-19
# 2  2026-01-19T05:00:46.000Z                  1.0           1    2026-01-19
# 3                       NaN                  1.0           1    2026-01-19
# 4                       NaN                  1.0           1    2026-01-19
#
#   operatorUICCode operatorShortCode trainType  trainCategory commuterLineID
# 0              10                vr        IC  Long-distance
# 1              10                vr        IC  Long-distance
# 2              10                vr        IC  Long-distance
# 3              10                vr        IC  Long-distance
# 4              10                vr        IC  Long-distance

# %%
trains.tail()
# Out:
#        stationShortCode       type  cancelled             scheduledTime  \
# 498173              LOP    ARRIVAL      False  2026-01-25T16:42:34.000Z
# 498174              LOP  DEPARTURE      False  2026-01-25T16:42:34.000Z
# 498175              PSL    ARRIVAL      False  2026-01-25T16:43:30.000Z
# 498176              PSL  DEPARTURE      False  2026-01-25T16:44:00.000Z
# 498177              HKI    ARRIVAL      False  2026-01-25T16:49:00.000Z
#
#                       actualTime  differenceInMinutes trainNumber  \
# 498173                       NaN                  4.0       89700
# 498174                       NaN                  4.0       89700
# 498175  2026-01-25T16:47:47.000Z                  4.0       89700
# 498176  2026-01-25T16:48:13.000Z                  4.0       89700
# 498177  2026-01-25T16:52:31.000Z                  4.0       89700
#
#        departureDate operatorUICCode operatorShortCode trainType  \
# 498173    2026-01-25              10                vr        HL
# 498174    2026-01-25              10                vr        HL
# 498175    2026-01-25              10                vr        HL
# 498176    2026-01-25              10                vr        HL
# 498177    2026-01-25              10                vr        HL
#
#        trainCategory commuterLineID
# 498173      Commuter              R
# 498174      Commuter              R
# 498175      Commuter              R
# 498176      Commuter              R
# 498177      Commuter              R

# %%
columns = ['departureDate', 'trainNumber', 'trainCategory', 'trainType', 'commuterLineID', 'stationShortCode', 'type', 
           'scheduledTime', 'actualTime', 'differenceInMinutes', 'operatorUICCode', 'operatorShortCode', 'cancelled']

trains = trains[columns]
trains.head()
# Out:
#   departureDate trainNumber  trainCategory trainType commuterLineID  \
# 0    2026-01-19           1  Long-distance        IC
# 1    2026-01-19           1  Long-distance        IC
# 2    2026-01-19           1  Long-distance        IC
# 3    2026-01-19           1  Long-distance        IC
# 4    2026-01-19           1  Long-distance        IC
#
#   stationShortCode       type             scheduledTime  \
# 0              HKI  DEPARTURE  2026-01-19T04:54:00.000Z
# 1              PSL    ARRIVAL  2026-01-19T04:59:00.000Z
# 2              PSL  DEPARTURE  2026-01-19T05:00:00.000Z
# 3              LOP    ARRIVAL  2026-01-19T05:00:53.000Z
# 4              LOP  DEPARTURE  2026-01-19T05:00:53.000Z
#
#                  actualTime  differenceInMinutes operatorUICCode  \
# 0  2026-01-19T04:54:31.000Z                  1.0              10
# 1  2026-01-19T04:59:11.000Z                  0.0              10
# 2  2026-01-19T05:00:46.000Z                  1.0              10
# 3                       NaN                  1.0              10
# 4                       NaN                  1.0              10
#
#   operatorShortCode  cancelled
# 0                vr      False
# 1                vr      False
# 2                vr      False
# 3                vr      False
# 4                vr      False

# %%
print(f'Dataframessa on {trains.shape[0]} riviä ja {trains.shape[1]} saraketta.')
# Out:
# Dataframessa on 498178 riviä ja 13 saraketta.

# %% [markdown]
# ## Junatiedot .parquet-muotoon

# %%
week_number = first_day_of_previous_week.isocalendar().week
year = first_day_of_previous_week.year
trains.to_parquet(rf'Data\vr_trains_{year}_week_{week_number}.parquet', index=False)
