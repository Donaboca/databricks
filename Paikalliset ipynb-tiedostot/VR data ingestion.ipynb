# %% [markdown]
# # Edellisen viikon junatiedot

# %%
import requests
from requests.exceptions import HTTPError
import pandas as pd
import datetime as dt

today = dt.date.today()
first_day_of_current_week = today - dt.timedelta(days=today.weekday())
first_day_of_previous_week = first_day_of_current_week - dt.timedelta(weeks=1)
last_day_of_previous_week = first_day_of_current_week - dt.timedelta(days=1)


base_api_url = 'https://rata.digitraffic.fi/api/v1/trains/'
json_list = []

try:
    for date in pd.date_range(first_day_of_previous_week, last_day_of_previous_week):
        response = requests.get(base_api_url + date.strftime('%Y-%m-%d'))
        response.raise_for_status()
        trains_json = response.json()
        if isinstance(trains_json, list):
            json_list.extend(trains_json)
        else:
            json_list.append(trains_json)
    print(f'Data noudettu onnistuneesti {first_day_of_previous_week.strftime('%d.%m.%Y')} - {last_day_of_previous_week.strftime('%d.%m.%Y')} väliseltä ajalta.')
except HTTPError as http_err:
    print(f'Datan noutamisessa tapahtui virhe: {http_err}')
except Exception as err:
    print(f'Tapahtui odottamaton virhe: {err}')
# Out:
# Data noudettu onnistuneesti 01.02.2026 - 22.02.2026 väliseltä ajalta.

# %%
json_list[0]
# Out:
# {'trainNumber': 1,
#  'departureDate': '2026-02-01',
#  'operatorUICCode': 10,
#  'operatorShortCode': 'vr',
#  'trainType': 'S',
#  'trainCategory': 'Long-distance',
#  'commuterLineID': '',
#  'runningCurrently': False,
#  'cancelled': False,
#  'version': 293249395548,
#  'timetableType': 'REGULAR',
#  'timetableAcceptanceDate': '2025-10-30T06:30:01.000Z',
#  'timeTableRows': [{'stationShortCode': 'HKI',
#    'stationUICCode': 1,
#    'countryCode': 'FI',
#    'type': 'DEPARTURE',
#    'trainStopping': True,
#    'commercialStop': True,
#    'cancelled': False,
#    'scheduledTime': '2026-02-01T04:54:00.000Z',
#    'actualTime': '2026-02-01T04:56:35.000Z',
#    'differenceInMinutes': 3,
#    'causes': [],
#    'commercialTrack': '10',
#    'trainReady': {'source': 'KUPLA',
#     'accepted': True,
#     'timestamp': '2026-02-01T04:52:43.000Z'}},
#   {'stationShortCode': 'PSL',
#    'stationUICCode': 10,
#    'countryCode': 'FI',
#    'type': 'ARRIVAL',
#    'trainStopping': True,
#    'commercialStop': True,
#    'cancelled': False,
#    'scheduledTime': '2026-02-01T04:59:00.000Z',
#    'actualTime': '2026-02-01T05:01:20.000Z',
#    'differenceInMinutes': 2,
#    'causes': [],
#    'commercialTrack': '4'},
#   {'stationShortCode': 'PSL',
#    'stationUICCode': 10,
#    'countryCode': 'FI',
#    'type': 'DEPARTURE',
#    'trainStopping': True,
#    'commercialStop': True,
#    'cancelled': False,
#    'scheduledTime': '2026-02-01T05:00:00.000Z',
#    'actualTime': '2026-02-01T05:02:53.000Z',
#    'differenceInMinutes': 3,
#    'causes': [],
#    'commercialTrack': '4'},
#   {'stationShortCode': 'LOP',
#    'stationUICCode': 1370,
#    'countryCode': 'FI',
#    'type': 'ARRIVAL',
#    'trainStopping': False,
#    'cancelled': False,
#    'scheduledTime': '2026-02-01T05:00:53.000Z',
#    'estimateSource': 'LIIKE_AUTOMATIC',
#    'differenceInMinutes': 3,
#    'causes': [],
#    'commercialTrack': '',
#    'liveEstimateTime': '2026-02-01T05:03:46.000Z'},
#   {'stationShortCode': 'LOP',
#    'stationUICCode': 1370,
#    'countryCode': 'FI',
#    'type': 'DEPARTURE',
#    'trainStopping': False,
#    'cancelled': False,
#    'scheduledTime': '2026-02-01T05:00:53.000Z',
#    'estimateSource': 'LIIKE_AUTOMATIC',
#    'differenceInMinutes': 3,
#    'causes': [],
#    'commercialTrack': '',
#    'liveEstimateTime': '2026-02-01T05:03:46.000Z'},
#   {'stationShortCode': 'KÄP',
#    'stationUICCode': 977,
#    'countryCode': 'FI',
#    'type': 'ARRIVAL',
#    'trainStopping': False,
#    'cancelled': False,
#    'scheduledTime': '2026-02-01T05:02:00.000Z',
#    'actualTime': '2026-02-01T05:05:04.000Z',
#    'differenceInMinutes': 3,
#    'causes': [],
#    'commercialTrack': ''},
#   {'stationShortCode': 'KÄP',
#    'stationUICCode': 977,
#    'countryCode': 'FI',
#    'type': 'DEPARTURE',
#    'trainStopping': False,
#    'cancelled': False,
#    'scheduledTime': '2026-02-01T05:02:00.000Z',
#    'actualTime': '2026-02-01T05:05:04.000Z',
#    'differenceInMinutes': 3,
#    'causes': [],
#    'commercialTrack': ''},
#   {'stationShortCode': 'OLK',
#    'stationUICCode': 15,
#    'countryCode': 'FI',
#    'type': 'ARRIVAL',
#    'trainStopping': False,
#    'cancelled': False,
#    'scheduledTime': '2026-02-01T05:03:00.000Z',
#    'actualTime': '2026-02-01T05:05:48.000Z',
#    'differenceInMinutes': 3,
#    'causes': [],
#    'commercialTrack': ''},
#   {'stationShortCode': 'OLK',
#    'stationUICCode': 15,
#    'countryCode': 'FI',
#    'type': 'DEPARTURE',
#    'trainStopping': False,
#    'cancelled': False,
#    'scheduledTime': '2026-02-01T05:03:00.000Z',
#    'actualTime': '2026-02-01T05:05:48.000Z',
#    'differenceInMinutes': 3,
#    'causes': [],
#    'commercialTrack': ''},
#   {'stationShortCode': 'VRJ',
#    'stationUICCode': 1371,
#    'countryCode': 'FI',
#    'type': 'ARRIVAL',
#    'trainStopping': False,
#    'cancelled': False,
#    'scheduledTime': '2026-02-01T05:03:16.000Z',
#    'estimateSource': 'LIIKE_AUTOMATIC',
#    'differenceInMinutes': 3,
#    'causes': [],
#    'commercialTrack': '',
#    'liveEstimateTime': '2026-02-01T05:05:55.000Z'},
#   {'stationShortCode': 'VRJ',
#    'stationUICCode': 1371,
#    'countryCode': 'FI',
#    'type': 'DEPARTURE',
#    'trainStopping': False,
#    'cancelled': False,
#    'scheduledTime': '2026-02-01T05:03:16.000Z',
#    'estimateSource': 'LIIKE_AUTOMATIC',
#    'differenceInMinutes': 3,
#    'causes': [],
#    'commercialTrack': '',
#    'liveEstimateTime': '2026-02-01T05:05:55.000Z'},
#   {'stationShortCode': 'PMK',
#    'stationUICCode': 551,
#    'countryCode': 'FI',
#    'type': 'ARRIVAL',
#    'trainStopping': False,
#    'cancelled': False,
#    'scheduledTime': '2026-02-01T05:04:09.000Z',
#    'actualTime': '2026-02-01T05:06:39.000Z',
#    'differenceInMinutes': 3,
#    'causes': [],
#    'commercialTrack': ''},
#   {'stationShortCode': 'PMK',
#    'stationUICCode': 551,
#    'countryCode': 'FI',
#    'type': 'DEPARTURE',
#    'trainStopping': False,
#    'cancelled': False,
#    'scheduledTime': '2026-02-01T05:04:09.000Z',
#    'actualTime': '2026-02-01T05:06:39.000Z',
#    'differenceInMinutes': 3,
#    'causes': [],
#    'commercialTrack': ''},
#   {'stationShortCode': 'ML',
#    'stationUICCode': 17,
#    'countryCode': 'FI',
#    'type': 'ARRIVAL',
#    'trainStopping': False,
#    'cancelled': False,
#    'scheduledTime': '2026-02-01T05:05:00.000Z',
#    'actualTime': '2026-02-01T05:07:23.000Z',
#    'differenceInMinutes': 2,
#    'causes': [],
#    'commercialTrack': '2'},
#   {'stationShortCode': 'ML',
#    'stationUICCode': 17,
#    'countryCode': 'FI',
#    'type': 'DEPARTURE',
#    'trainStopping': False,
#    'cancelled': False,
#    'scheduledTime': '2026-02-01T05:05:00.000Z',
#    'actualTime': '2026-02-01T05:07:23.000Z',
#    'differenceInMinutes': 2,
#    'causes': [],
#    'commercialTrack': '2'},
#   {'stationShortCode': 'TNA',
#    'stationUICCode': 552,
#    'countryCode': 'FI',
#    'type': 'ARRIVAL',
#    'trainStopping': False,
#    'cancelled': False,
#    'scheduledTime': '2026-02-01T05:06:22.000Z',
#    'actualTime': '2026-02-01T05:07:55.000Z',
#    'differenceInMinutes': 2,
#    'causes': [],
#    'commercialTrack': ''},
#   {'stationShortCode': 'TNA',
#    'stationUICCode': 552,
#    'countryCode': 'FI',
#    'type': 'DEPARTURE',
#    'trainStopping': False,
#    'cancelled': False,
#    'scheduledTime': '2026-02-01T05:06:22.000Z',
#    'actualTime': '2026-02-01T05:07:55.000Z',
#    'differenceInMinutes': 2,
#    'causes': [],
#    'commercialTrack': ''},
#   {'stationShortCode': 'PLA',
#    'stationUICCode': 553,
#    'countryCode': 'FI',
#    'type': 'ARRIVAL',
#    'trainStopping': False,
#    'cancelled': False,
#    'scheduledTime': '2026-02-01T05:07:31.000Z',
#    'actualTime': '2026-02-01T05:08:51.000Z',
#    'differenceInMinutes': 1,
#    'causes': [],
#    'commercialTrack': ''},
#   {'stationShortCode': 'PLA',
#    'stationUICCode': 553,
#    'countryCode': 'FI',
#    'type': 'DEPARTURE',
#    'trainStopping': False,
#    'cancelled': False,
#    'scheduledTime': '2026-02-01T05:07:31.000Z',
#    'actualTime': '2026-02-01T05:08:51.000Z',
#    'differenceInMinutes': 1,
#    'causes': [],
#    'commercialTrack': ''},
#   {'stationShortCode': 'TKL',
#    'stationUICCode': 18,
#    'countryCode': 'FI',
#    'type': 'ARRIVAL',
#    'trainStopping': True,
#    'commercialStop': True,
#    'cancelled': False,
#    'scheduledTime': '2026-02-01T05:09:00.000Z',
#    'actualTime': '2026-02-01T05:10:45.000Z',
#    'differenceInMinutes': 2,
#    'causes': [],
#    'commercialTrack': '3'},
#   {'stationShortCode': 'TKL',
#    'stationUICCode': 18,
#    'countryCode': 'FI',
#    'type': 'DEPARTURE',
#    'trainStopping': True,
#    'commercialStop': True,
#    'cancelled': False,
#    'scheduledTime': '2026-02-01T05:11:00.000Z',
#    'actualTime': '2026-02-01T05:12:57.000Z',
#    'differenceInMinutes': 2,
#    'causes': [],
#    'commercialTrack': '3'},
#   {'stationShortCode': 'HKH',
#    'stationUICCode': 556,
#    'countryCode': 'FI',
#    'type': 'ARRIVAL',
#    'trainStopping': False,
#    'cancelled': False,
#    'scheduledTime': '2026-02-01T05:12:20.000Z',
#    'actualTime': '2026-02-01T05:14:15.000Z',
#    'differenceInMinutes': 2,
#    'causes': [],
#    'commercialTrack': ''},
#   {'stationShortCode': 'HKH',
#    'stationUICCode': 556,
#    'countryCode': 'FI',
#    'type': 'DEPARTURE',
#    'trainStopping': False,
#    'cancelled': False,
#    'scheduledTime': '2026-02-01T05:12:20.000Z',
#    'actualTime': '2026-02-01T05:14:15.000Z',
#    'differenceInMinutes': 2,
#    'causes': [],
#    'commercialTrack': ''},
#   {'stationShortCode': 'HVK',
#    'stationUICCode': 1334,
#    'countryCode': 'FI',
#    'type': 'ARRIVAL',
#    'trainStopping': False,
#    'cancelled': False,
#    'scheduledTime': '2026-02-01T05:13:00.000Z',
#    'estimateSource': 'LIIKE_AUTOMATIC',
#    'differenceInMinutes': 2,
#    'causes': [],
#    'commercialTrack': '',
#    'liveEstimateTime': '2026-02-01T05:14:31.000Z'},
#   {'stationShortCode': 'HVK',
#    'stationUICCode': 1334,
#    'countryCode': 'FI',
#    'type': 'DEPARTURE',
#    'trainStopping': False,
#    'cancelled': False,
#    'scheduledTime': '2026-02-01T05:13:00.000Z',
#    'estimateSource': 'LIIKE_AUTOMATIC',
#    'differenceInMinutes': 2,
#    'causes': [],
#    'commercialTrack': '',
#    'liveEstimateTime': '2026-02-01T05:14:31.000Z'},
#   {'stationShortCode': 'KVY',
#    'stationUICCode': 559,
#    'countryCode': 'FI',
#    'type': 'ARRIVAL',
#    'trainStopping': False,
#    'cancelled': False,
#    'scheduledTime': '2026-02-01T05:13:56.000Z',
#    'actualTime': '2026-02-01T05:15:25.000Z',
#    'differenceInMinutes': 1,
#    'causes': [],
#    'commercialTrack': ''},
#   {'stationShortCode': 'KVY',
#    'stationUICCode': 559,
#    'countryCode': 'FI',
#    'type': 'DEPARTURE',
#    'trainStopping': False,
#    'cancelled': False,
#    'scheduledTime': '2026-02-01T05:13:56.000Z',
#    'actualTime': '2026-02-01T05:15:25.000Z',
#    'differenceInMinutes': 1,
#    'causes': [],
#    'commercialTrack': ''},
#   {'stationShortCode': 'RKL',
#    'stationUICCode': 554,
#    'countryCode': 'FI',
#    'type': 'ARRIVAL',
#    'trainStopping': False,
#    'cancelled': False,
#    'scheduledTime': '2026-02-01T05:14:34.000Z',
#    'actualTime': '2026-02-01T05:16:00.000Z',
#    'differenceInMinutes': 1,
#    'causes': [],
#    'commercialTrack': ''},
#   {'stationShortCode': 'RKL',
#    'stationUICCode': 554,
#    'countryCode': 'FI',
#    'type': 'DEPARTURE',
#    'trainStopping': False,
#    'cancelled': False,
#    'scheduledTime': '2026-02-01T05:14:34.000Z',
#    'actualTime': '2026-02-01T05:16:00.000Z',
#    'differenceInMinutes': 1,
#    'causes': [],
#    'commercialTrack': ''},
#   {'stationShortCode': 'HNA',
#    'stationUICCode': 1018,
#    'countryCode': 'FI',
#    'type': 'ARRIVAL',
#    'trainStopping': False,
#    'cancelled': False,
#    'scheduledTime': '2026-02-01T05:15:00.000Z',
#    'actualTime': '2026-02-01T05:16:29.000Z',
#    'differenceInMinutes': 1,
#    'causes': [],
#    'commercialTrack': ''},
#   {'stationShortCode': 'HNA',
#    'stationUICCode': 1018,
#    'countryCode': 'FI',
#    'type': 'DEPARTURE',
#    'trainStopping': False,
#    'cancelled': False,
#    'scheduledTime': '2026-02-01T05:15:00.000Z',
#    'actualTime': '2026-02-01T05:16:29.000Z',
#    'differenceInMinutes': 1,
#    'causes': [],
#    'commercialTrack': ''},
#   {'stationShortCode': 'KRS',
#    'stationUICCode': 19,
#    'countryCode': 'FI',
#    'type': 'ARRIVAL',
#    'trainStopping': False,
#    'cancelled': False,
#    'scheduledTime': '2026-02-01T05:15:37.000Z',
#    'actualTime': '2026-02-01T05:17:21.000Z',
#    'differenceInMinutes': 2,
#    'causes': [],
#    'commercialTrack': ''},
#   {'stationShortCode': 'KRS',
#    'stationUICCode': 19,
#    'countryCode': 'FI',
#    'type': 'DEPARTURE',
#    'trainStopping': False,
#    'cancelled': False,
#    'scheduledTime': '2026-02-01T05:15:37.000Z',
#    'actualTime': '2026-02-01T05:17:21.000Z',
#    'differenceInMinutes': 2,
#    'causes': [],
#    'commercialTrack': ''},
#   {'stationShortCode': 'SAV',
#    'stationUICCode': 555,
#    'countryCode': 'FI',
#    'type': 'ARRIVAL',
#    'trainStopping': False,
#    'cancelled': False,
#    'scheduledTime': '2026-02-01T05:17:17.000Z',
#    'actualTime': '2026-02-01T05:18:37.000Z',
#    'differenceInMinutes': 1,
#    'causes': [],
#    'commercialTrack': ''},
#   {'stationShortCode': 'SAV',
#    'stationUICCode': 555,
#    'countryCode': 'FI',
#    'type': 'DEPARTURE',
#    'trainStopping': False,
#    'cancelled': False,
#    'scheduledTime': '2026-02-01T05:17:17.000Z',
#    'actualTime': '2026-02-01T05:18:37.000Z',
#    'differenceInMinutes': 1,
#    'causes': [],
#    'commercialTrack': ''},
#   {'stationShortCode': 'KE',
#    'stationUICCode': 20,
#    'countryCode': 'FI',
#    'type': 'ARRIVAL',
#    'trainStopping': False,
#    'cancelled': False,
#    'scheduledTime': '2026-02-01T05:18:30.000Z',
#    'actualTime': '2026-02-01T05:19:54.000Z',
#    'differenceInMinutes': 1,
#    'causes': [],
#    'commercialTrack': ''},
#   {'stationShortCode': 'KE',
#    'stationUICCode': 20,
#    'countryCode': 'FI',
#    'type': 'DEPARTURE',
#    'trainStopping': False,
#    'cancelled': False,
#    'scheduledTime': '2026-02-01T05:18:30.000Z',
#    'actualTime': '2026-02-01T05:19:54.000Z',
#    'differenceInMinutes': 1,
#    'causes': [],
#    'commercialTrack': ''},
#   {'stationShortCode': 'KYT',
#    'stationUICCode': 1111,
#    'countryCode': 'FI',
#    'type': 'ARRIVAL',
#    'trainStopping': False,
#    'cancelled': False,
#    'scheduledTime': '2026-02-01T05:20:00.000Z',
#    'actualTime': '2026-02-01T05:20:51.000Z',
#    'differenceInMinutes': 1,
#    'causes': [],
#    'commercialTrack': ''},
#   {'stationShortCode': 'KYT',
#    'stationUICCode': 1111,
#    'countryCode': 'FI',
#    'type': 'DEPARTURE',
#    'trainStopping': False,
#    'cancelled': False,
#    'scheduledTime': '2026-02-01T05:20:00.000Z',
#    'actualTime': '2026-02-01T05:20:51.000Z',
#    'differenceInMinutes': 1,
#    'causes': [],
#    'commercialTrack': ''},
#   {'stationShortCode': 'HAA',
#    'stationUICCode': 13,
#    'countryCode': 'FI',
#    'type': 'ARRIVAL',
#    'trainStopping': False,
#    'cancelled': False,
#    'scheduledTime': '2026-02-01T05:24:00.000Z',
#    'actualTime': '2026-02-01T05:24:06.000Z',
#    'differenceInMinutes': 0,
#    'causes': [],
#    'commercialTrack': ''},
#   {'stationShortCode': 'HAA',
#    'stationUICCode': 13,
#    'countryCode': 'FI',
#    'type': 'DEPARTURE',
#    'trainStopping': False,
#    'cancelled': False,
#    'scheduledTime': '2026-02-01T05:24:00.000Z',
#    'actualTime': '2026-02-01T05:24:06.000Z',
#    'differenceInMinutes': 0,
#    'causes': [],
#    'commercialTrack': ''},
#   {'stationShortCode': 'KSU',
#    'stationUICCode': 1128,
#    'countryCode': 'FI',
#    'type': 'ARRIVAL',
#    'trainStopping': False,
#    'cancelled': False,
#    'scheduledTime': '2026-02-01T05:28:00.000Z',
#    'actualTime': '2026-02-01T05:27:45.000Z',
#    'differenceInMinutes': 0,
#    'causes': [],
#    'commercialTrack': ''},
#   {'stationShortCode': 'KSU',
#    'stationUICCode': 1128,
#    'countryCode': 'FI',
#    'type': 'DEPARTURE',
#    'trainStopping': False,
#    'cancelled': False,
#    'scheduledTime': '2026-02-01T05:28:00.000Z',
#    'actualTime': '2026-02-01T05:27:45.000Z',
#    'differenceInMinutes': 0,
#    'causes': [],
#    'commercialTrack': ''},
#   {'stationShortCode': 'MLÄ',
#    'stationUICCode': 27,
#    'countryCode': 'FI',
#    'type': 'ARRIVAL',
#    'trainStopping': False,
#    'cancelled': False,
#    'scheduledTime': '2026-02-01T05:31:00.000Z',
#    'actualTime': '2026-02-01T05:30:53.000Z',
#    'differenceInMinutes': 0,
#    'causes': [],
#    'commercialTrack': ''},
#   {'stationShortCode': 'MLÄ',
#    'stationUICCode': 27,
#    'countryCode': 'FI',
#    'type': 'DEPARTURE',
#    'trainStopping': False,
#    'cancelled': False,
#    'scheduledTime': '2026-02-01T05:31:00.000Z',
#    'actualTime': '2026-02-01T05:30:53.000Z',
#    'differenceInMinutes': 0,
#    'causes': [],
#    'commercialTrack': ''},
#   {'stationShortCode': 'SIP',
#    'stationUICCode': 1254,
#    'countryCode': 'FI',
#    'type': 'ARRIVAL',
#    'trainStopping': False,
#    'cancelled': False,
#    'scheduledTime': '2026-02-01T05:34:30.000Z',
#    'actualTime': '2026-02-01T05:34:00.000Z',
#    'differenceInMinutes': 0,
#    'causes': [],
#    'commercialTrack': ''},
#   {'stationShortCode': 'SIP',
#    'stationUICCode': 1254,
#    'countryCode': 'FI',
#    'type': 'DEPARTURE',
#    'trainStopping': False,
#    'cancelled': False,
#    'scheduledTime': '2026-02-01T05:34:30.000Z',
#    'actualTime': '2026-02-01T05:34:00.000Z',
#    'differenceInMinutes': 0,
#    'causes': [],
#    'commercialTrack': ''},
#   {'stationShortCode': 'HNN',
#    'stationUICCode': 1164,
#    'countryCode': 'FI',
#    'type': 'ARRIVAL',
#    'trainStopping': False,
#    'cancelled': False,
#    'scheduledTime': '2026-02-01T05:38:00.000Z',
#    'actualTime': '2026-02-01T05:37:40.000Z',
#    'differenceInMinutes': 0,
#    'causes': [],
#    'commercialTrack': ''},
#   {'stationShortCode': 'HNN',
#    'stationUICCode': 1164,
#    'countryCode': 'FI',
#    'type': 'DEPARTURE',
#    'trainStopping': False,
#    'cancelled': False,
#    'scheduledTime': '2026-02-01T05:38:00.000Z',
#    'actualTime': '2026-02-01T05:37:40.000Z',
#    'differenceInMinutes': 0,
#    'causes': [],
#    'commercialTrack': ''},
#   {'stationShortCode': 'HLT',
#    'stationUICCode': 1014,
#    'countryCode': 'FI',
#    'type': 'ARRIVAL',
#    'trainStopping': False,
#    'cancelled': False,
#    'scheduledTime': '2026-02-01T05:43:00.000Z',
#    'actualTime': '2026-02-01T05:44:05.000Z',
#    'differenceInMinutes': 1,
#    'causes': [],
#    'commercialTrack': ''},
#   {'stationShortCode': 'HLT',
#    'stationUICCode': 1014,
#    'countryCode': 'FI',
#    'type': 'DEPARTURE',
#    'trainStopping': False,
#    'cancelled': False,
#    'scheduledTime': '2026-02-01T05:43:00.000Z',
#    'actualTime': '2026-02-01T05:44:05.000Z',
#    'differenceInMinutes': 1,
#    'causes': [],
#    'commercialTrack': ''},
#   {'stationShortCode': 'LH',
#    'stationUICCode': 100,
#    'countryCode': 'FI',
#    'type': 'ARRIVAL',
#    'trainStopping': True,
#    'commercialStop': True,
#    'cancelled': False,
#    'scheduledTime': '2026-02-01T05:49:00.000Z',
#    'actualTime': '2026-02-01T05:51:23.000Z',
#    'differenceInMinutes': 2,
#    'causes': [],
#    'commercialTrack': '1'},
#   {'stationShortCode': 'LH',
#    'stationUICCode': 100,
#    'countryCode': 'FI',
#    'type': 'DEPARTURE',
#    'trainStopping': True,
#    'commercialStop': True,
#    'cancelled': False,
#    'scheduledTime': '2026-02-01T05:51:00.000Z',
#    'estimateSource': 'LIIKE_USER',
#    'actualTime': '2026-02-01T05:58:19.000Z',
#    'differenceInMinutes': 7,
#    'causes': [{'categoryCode': 'K',
#      'detailedCategoryCode': 'K2',
#      'categoryCodeId': 285280330,
#      'detailedCategoryCodeId': 152109320}],
#    'commercialTrack': '1',
#    'liveEstimateTime': '2026-02-01T06:01:00.000Z'},
#   {'stationShortCode': 'VLH',
#    'stationUICCode': 104,
#    'countryCode': 'FI',
#    'type': 'ARRIVAL',
#    'trainStopping': False,
#    'cancelled': False,
#    'scheduledTime': '2026-02-01T05:56:00.000Z',
#    'actualTime': '2026-02-01T06:03:40.000Z',
#    'differenceInMinutes': 8,
#    'causes': [],
#    'commercialTrack': '2'},
#   {'stationShortCode': 'VLH',
#    'stationUICCode': 104,
#    'countryCode': 'FI',
#    'type': 'DEPARTURE',
#    'trainStopping': False,
#    'cancelled': False,
#    'scheduledTime': '2026-02-01T05:56:00.000Z',
#    'actualTime': '2026-02-01T06:03:40.000Z',
#    'differenceInMinutes': 8,
#    'causes': [],
#    'commercialTrack': '2'},
#   {'stationShortCode': 'NSL',
#    'stationUICCode': 595,
#    'countryCode': 'FI',
#    'type': 'ARRIVAL',
#    'trainStopping': False,
#    'cancelled': False,
#    'scheduledTime': '2026-02-01T05:58:00.000Z',
#    'actualTime': '2026-02-01T06:05:53.000Z',
#    'differenceInMinutes': 8,
#    'causes': [],
#    'commercialTrack': '1'},
#   {'stationShortCode': 'NSL',
#    'stationUICCode': 595,
#    'countryCode': 'FI',
#    'type': 'DEPARTURE',
#    'trainStopping': False,
#    'cancelled': False,
#    'scheduledTime': '2026-02-01T05:58:00.000Z',
#    'actualTime': '2026-02-01T06:05:53.000Z',
#    'differenceInMinutes': 8,
#    'causes': [],
#    'commercialTrack': '1'},
#   {'stationShortCode': 'UKÄ',
#    'stationUICCode': 105,
#    'countryCode': 'FI',
#    'type': 'ARRIVAL',
#    'trainStopping': False,
#    'cancelled': False,
#    'scheduledTime': '2026-02-01T05:59:30.000Z',
#    'actualTime': '2026-02-01T06:07:12.000Z',
#    'differenceInMinutes': 8,
#    'causes': [],
#    'commercialTrack': '1'},
#   {'stationShortCode': 'UKÄ',
#    'stationUICCode': 105,
#    'countryCode': 'FI',
#    'type': 'DEPARTURE',
#    'trainStopping': False,
#    'cancelled': False,
#    'scheduledTime': '2026-02-01T05:59:30.000Z',
#    'actualTime': '2026-02-01T06:07:12.000Z',
#    'differenceInMinutes': 8,
#    'causes': [],
#    'commercialTrack': '1'},
#   {'stationShortCode': 'MKA',
#    'stationUICCode': 1336,
#    'countryCode': 'FI',
#    'type': 'ARRIVAL',
#    'trainStopping': False,
#    'cancelled': False,
#    'scheduledTime': '2026-02-01T06:03:30.000Z',
#    'actualTime': '2026-02-01T06:11:39.000Z',
#    'differenceInMinutes': 8,
#    'causes': [],
#    'commercialTrack': ''},
#   {'stationShortCode': 'MKA',
#    'stationUICCode': 1336,
#    'countryCode': 'FI',
#    'type': 'DEPARTURE',
#    'trainStopping': False,
#    'cancelled': False,
#    'scheduledTime': '2026-02-01T06:03:30.000Z',
#    'actualTime': '2026-02-01T06:11:39.000Z',
#    'differenceInMinutes': 8,
#    'causes': [],
#    'commercialTrack': ''},
#   {'stationShortCode': 'KA',
#    'stationUICCode': 477,
#    'countryCode': 'FI',
#    'type': 'ARRIVAL',
#    'trainStopping': False,
#    'cancelled': False,
#    'scheduledTime': '2026-02-01T06:07:00.000Z',
#    'actualTime': '2026-02-01T06:15:00.000Z',
#    'differenceInMinutes': 8,
#    'causes': [],
#    'commercialTrack': '2'},
#   {'stationShortCode': 'KA',
#    'stationUICCode': 477,
#    'countryCode': 'FI',
#    'type': 'DEPARTURE',
#    'trainStopping': False,
#    'cancelled': False,
#    'scheduledTime': '2026-02-01T06:07:00.000Z',
#    'actualTime': '2026-02-01T06:15:00.000Z',
#    'differenceInMinutes': 8,
#    'causes': [],
#    'commercialTrack': '2'},
#   {'stationShortCode': 'NMÄ',
#    'stationUICCode': 1324,
#    'countryCode': 'FI',
#    'type': 'ARRIVAL',
#    'trainStopping': False,
#    'cancelled': False,
#    'scheduledTime': '2026-02-01T06:08:00.000Z',
#    'actualTime': '2026-02-01T06:16:02.000Z',
#    'differenceInMinutes': 8,
#    'causes': [],
#    'commercialTrack': ''},
#   {'stationShortCode': 'NMÄ',
#    'stationUICCode': 1324,
#    'countryCode': 'FI',
#    'type': 'DEPARTURE',
#    'trainStopping': False,
#    'cancelled': False,
#    'scheduledTime': '2026-02-01T06:08:00.000Z',
#    'actualTime': '2026-02-01T06:16:02.000Z',
#    'differenceInMinutes': 8,
#    'causes': [],
#    'commercialTrack': ''},
#   {'stationShortCode': 'SMÄ',
#    'stationUICCode': 1325,
#    'countryCode': 'FI',
#    'type': 'ARRIVAL',
#    'trainStopping': False,
#    'cancelled': False,
#    'scheduledTime': '2026-02-01T06:11:00.000Z',
#    'actualTime': '2026-02-01T06:18:53.000Z',
#    'differenceInMinutes': 8,
#    'causes': [],
#    'commercialTrack': ''},
#   {'stationShortCode': 'SMÄ',
#    'stationUICCode': 1325,
#    'countryCode': 'FI',
#    'type': 'DEPARTURE',
#    'trainStopping': False,
#    'cancelled': False,
#    'scheduledTime': '2026-02-01T06:11:00.000Z',
#    'actualTime': '2026-02-01T06:18:53.000Z',
#    'differenceInMinutes': 8,
#    'causes': [],
#    'commercialTrack': ''},
#   {'stationShortCode': 'KRA',
#    'stationUICCode': 478,
#    'countryCode': 'FI',
#    'type': 'ARRIVAL',
#    'trainStopping': False,
#    'cancelled': False,
#    'scheduledTime': '2026-02-01T06:14:00.000Z',
#    'actualTime': '2026-02-01T06:20:44.000Z',
#    'differenceInMinutes': 7,
#    'causes': [],
#    'commercialTrack': '1'},
#   {'stationShortCode': 'KRA',
#    'stationUICCode': 478,
#    'countryCode': 'FI',
#    'type': 'DEPARTURE',
#    'trainStopping': False,
#    'cancelled': False,
#    'scheduledTime': '2026-02-01T06:14:00.000Z',
#    'actualTime': '2026-02-01T06:20:44.000Z',
#    'differenceInMinutes': 7,
#    'causes': [],
#    'commercialTrack': '1'},
#   {'stationShortCode': 'KV',
#    'stationUICCode': 480,
#    'countryCode': 'FI',
#    'type': 'ARRIVAL',
#    'trainStopping': True,
#    'commercialStop': True,
#    'cancelled': False,
#    'scheduledTime': '2026-02-01T06:19:00.000Z',
#    'actualTime': '2026-02-01T06:24:28.000Z',
#    'differenceInMinutes': 5,
#    'causes': [],
#    'commercialTrack': '7'},
#   {'stationShortCode': 'KV',
#    'stationUICCode': 480,
#    'countryCode': 'FI',
#    'type': 'DEPARTURE',
#    'trainStopping': True,
#    'commercialStop': True,
#    'cancelled': False,
#    'scheduledTime': '2026-02-01T06:23:00.000Z',
#    'actualTime': '2026-02-01T06:26:50.000Z',
#    'differenceInMinutes': 4,
#    'causes': [],
#    'commercialTrack': '7'},
#   {'stationShortCode': 'KUV',
#    'stationUICCode': 1320,
#    'countryCode': 'FI',
#    'type': 'ARRIVAL',
#    'trainStopping': False,
#    'cancelled': False,
#    'scheduledTime': '2026-02-01T06:27:00.000Z',
#    'actualTime': '2026-02-01T06:30:12.000Z',
#    'differenceInMinutes': 3,
#    'causes': [],
#    'commercialTrack': ''},
#   {'stationShortCode': 'KUV',
#    'stationUICCode': 1320,
#    'countryCode': 'FI',
#    'type': 'DEPARTURE',
#    'trainStopping': False,
#    'cancelled': False,
#    'scheduledTime': '2026-02-01T06:27:00.000Z',
#    'actualTime': '2026-02-01T06:30:12.000Z',
#    'differenceInMinutes': 3,
#    'causes': [],
#    'commercialTrack': ''},
#   {'stationShortCode': 'UTI',
#    'stationUICCode': 484,
#    'countryCode': 'FI',
#    'type': 'ARRIVAL',
#    'trainStopping': False,
#    'cancelled': False,
#    'scheduledTime': '2026-02-01T06:30:00.000Z',
#    'actualTime': '2026-02-01T06:32:29.000Z',
#    'differenceInMinutes': 2,
#    'causes': [],
#    'commercialTrack': ''},
#   {'stationShortCode': 'UTI',
#    'stationUICCode': 484,
#    'countryCode': 'FI',
#    'type': 'DEPARTURE',
#    'trainStopping': False,
#    'cancelled': False,
#    'scheduledTime': '2026-02-01T06:30:00.000Z',
#    'actualTime': '2026-02-01T06:32:29.000Z',
#    'differenceInMinutes': 2,
#    'causes': [],
#    'commercialTrack': ''},
#   {'stationShortCode': 'KTH',
#    'stationUICCode': 1319,
#    'countryCode': 'FI',
#    'type': 'ARRIVAL',
#    'trainStopping': False,
#    'cancelled': False,
#    'scheduledTime': '2026-02-01T06:31:00.000Z',
#    'actualTime': '2026-02-01T06:33:06.000Z',
#    'differenceInMinutes': 2,
#    'causes': [],
#    'commercialTrack': ''},
#   {'stationShortCode': 'KTH',
#    'stationUICCode': 1319,
#    'countryCode': 'FI',
#    'type': 'DEPARTURE',
#    'trainStopping': False,
#    'cancelled': False,
#    'scheduledTime': '2026-02-01T06:31:00.000Z',
#    'actualTime': '2026-02-01T06:33:06.000Z',
#    'differenceInMinutes': 2,
#    'causes': [],
#    'commercialTrack': ''},
#   {'stationShortCode': 'KPA',
#    'stationUICCode': 485,
#    'countryCode': 'FI',
#    'type': 'ARRIVAL',
#    'trainStopping': False,
#    'cancelled': False,
#    'scheduledTime': '2026-02-01T06:34:00.000Z',
#    'actualTime': '2026-02-01T06:36:17.000Z',
#    'differenceInMinutes': 2,
#    'causes': [],
#    'commercialTrack': ''},
#   {'stationShortCode': 'KPA',
#    'stationUICCode': 485,
#    'countryCode': 'FI',
#    'type': 'DEPARTURE',
#    'trainStopping': False,
#    'cancelled': False,
#    'scheduledTime': '2026-02-01T06:34:00.000Z',
#    'actualTime': '2026-02-01T06:36:17.000Z',
#    'differenceInMinutes': 2,
#    'causes': [],
#    'commercialTrack': ''},
#   {'stationShortCode': 'KJR',
#    'stationUICCode': 944,
#    'countryCode': 'FI',
#    'type': 'ARRIVAL',
#    'trainStopping': False,
#    'cancelled': False,
#    'scheduledTime': '2026-02-01T06:38:00.000Z',
#    'actualTime': '2026-02-01T06:40:42.000Z',
#    'differenceInMinutes': 3,
#    'causes': [],
#    'commercialTrack': ''},
#   {'stationShortCode': 'KJR',
#    'stationUICCode': 944,
#    'countryCode': 'FI',
#    'type': 'DEPARTURE',
#    'trainStopping': False,
#    'cancelled': False,
#    'scheduledTime': '2026-02-01T06:38:00.000Z',
#    'actualTime': '2026-02-01T06:40:42.000Z',
#    'differenceInMinutes': 3,
#    'causes': [],
#    'commercialTrack': ''},
#   {'stationShortCode': 'TA',
#    'stationUICCode': 486,
#    'countryCode': 'FI',
#    'type': 'ARRIVAL',
#    'trainStopping': False,
#    'cancelled': False,
#    'scheduledTime': '2026-02-01T06:43:00.000Z',
#    'actualTime': '2026-02-01T06:44:37.000Z',
#    'differenceInMinutes': 2,
#    'causes': [],
#    'commercialTrack': ''},
#   {'stationShortCode': 'TA',
#    'stationUICCode': 486,
#    'countryCode': 'FI',
#    'type': 'DEPARTURE',
#    'trainStopping': False,
#    'cancelled': False,
#    'scheduledTime': '2026-02-01T06:43:00.000Z',
#    'actualTime': '2026-02-01T06:44:37.000Z',
#    'differenceInMinutes': 2,
#    'causes': [],
#    'commercialTrack': ''},
#   {'stationShortCode': 'LÄ',
#    'stationUICCode': 487,
#    'countryCode': 'FI',
#    'type': 'ARRIVAL',
#    'trainStopping': False,
#    'cancelled': False,
#    'scheduledTime': '2026-02-01T06:48:00.000Z',
#    'actualTime': '2026-02-01T06:49:08.000Z',
#    'differenceInMinutes': 1,
#    'causes': [],
#    'commercialTrack': ''},
#   {'stationShortCode': 'LÄ',
#    'stationUICCode': 487,
#    'countryCode': 'FI',
#    'type': 'DEPARTURE',
#    'trainStopping': False,
#    'cancelled': False,
#    'scheduledTime': '2026-02-01T06:48:00.000Z',
#    'actualTime': '2026-02-01T06:49:08.000Z',
#    'differenceInMinutes': 1,
#    'causes': [],
#    'commercialTrack': ''},
#   {'stationShortCode': 'RAS',
#    'stationUICCode': 1222,
#    'countryCode': 'FI',
#    'type': 'ARRIVAL',
#    'trainStopping': False,
#    'cancelled': False,
#    'scheduledTime': '2026-02-01T06:52:00.000Z',
#    'actualTime': '2026-02-01T06:52:31.000Z',
#    'differenceInMinutes': 1,
#    'causes': [],
#    'commercialTrack': ''},
#   {'stationShortCode': 'RAS',
#    'stationUICCode': 1222,
#    'countryCode': 'FI',
#    'type': 'DEPARTURE',
#    'trainStopping': False,
#    'cancelled': False,
#    'scheduledTime': '2026-02-01T06:52:00.000Z',
#    'actualTime': '2026-02-01T06:52:31.000Z',
#    'differenceInMinutes': 1,
#    'causes': [],
#    'commercialTrack': ''},
#   {'stationShortCode': 'TRÄ',
#    'stationUICCode': 1290,
#    'countryCode': 'FI',
#    'type': 'ARRIVAL',
#    'trainStopping': False,
#    'cancelled': False,
#    'scheduledTime': '2026-02-01T06:55:00.000Z',
#    'actualTime': '2026-02-01T06:55:00.000Z',
#    'differenceInMinutes': 0,
#    'causes': [],
#    'commercialTrack': ''},
#   {'stationShortCode': 'TRÄ',
#    'stationUICCode': 1290,
#    'countryCode': 'FI',
#    'type': 'DEPARTURE',
#    'trainStopping': False,
#    'cancelled': False,
#    'scheduledTime': '2026-02-01T06:55:00.000Z',
#    'actualTime': '2026-02-01T06:55:00.000Z',
#    'differenceInMinutes': 0,
#    'causes': [],
#    'commercialTrack': ''},
#   {'stationShortCode': 'TAP',
#    'stationUICCode': 1276,
#    'countryCode': 'FI',
#    'type': 'ARRIVAL',
#    'trainStopping': False,
#    'cancelled': False,
#    'scheduledTime': '2026-02-01T06:58:00.000Z',
#    'actualTime': '2026-02-01T06:57:24.000Z',
#    'differenceInMinutes': -1,
#    'causes': [],
#    'commercialTrack': ''},
#   {'stationShortCode': 'TAP',
#    'stationUICCode': 1276,
#    'countryCode': 'FI',
#    'type': 'DEPARTURE',
#    'trainStopping': False,
#    'cancelled': False,
#    'scheduledTime': '2026-02-01T06:58:00.000Z',
#    'actualTime': '2026-02-01T06:57:24.000Z',
#    'differenceInMinutes': -1,
#    'causes': [],
#    'commercialTrack': ''},
#   {'stationShortCode': 'LR',
#    'stationUICCode': 495,
#    'countryCode': 'FI',
#    'type': 'ARRIVAL',
#    'trainStopping': True,
#    'commercialStop': True,
#    'cancelled': False,
#    'scheduledTime': '2026-02-01T07:04:00.000Z',
#    'actualTime': '2026-02-01T07:02:55.000Z',
#    'differenceInMinutes': -1,
#    'causes': [],
#    'commercialTrack': '1'},
#   {'stationShortCode': 'LR',
#    'stationUICCode': 495,
#    'countryCode': 'FI',
#    'type': 'DEPARTURE',
#    'trainStopping': True,
#    'commercialStop': True,
#    'cancelled': False,
#    'scheduledTime': '2026-02-01T07:06:00.000Z',
#    'actualTime': '2026-02-01T07:06:49.000Z',
#    'differenceInMinutes': 1,
#    'causes': [],
#    'commercialTrack': '1'},
#   {'stationShortCode': 'LRS',
#    'stationUICCode': 498,
#    'countryCode': 'FI',
#    'type': 'ARRIVAL',
#    'trainStopping': False,
#    'cancelled': False,
#    'scheduledTime': '2026-02-01T07:10:00.000Z',
#    'actualTime': '2026-02-01T07:10:37.000Z',
#    'differenceInMinutes': 1,
#    'causes': [],
#    'commercialTrack': ''},
#   {'stationShortCode': 'LRS',
#    'stationUICCode': 498,
#    'countryCode': 'FI',
#    'type': 'DEPARTURE',
#    'trainStopping': False,
#    'cancelled': False,
#    'scheduledTime': '2026-02-01T07:10:00.000Z',
#    'actualTime': '2026-02-01T07:10:37.000Z',
#    'differenceInMinutes': 1,
#    'causes': [],
#    'commercialTrack': ''},
#   {'stationShortCode': 'MKO',
#    'stationUICCode': 1180,
#    'countryCode': 'FI',
#    'type': 'ARRIVAL',
#    'trainStopping': False,
#    'cancelled': False,
#    'scheduledTime': '2026-02-01T07:13:00.000Z',
#    'actualTime': '2026-02-01T07:13:47.000Z',
#    'differenceInMinutes': 1,
#    'causes': [],
#    'commercialTrack': ''},
#   {'stationShortCode': 'MKO',
#    'stationUICCode': 1180,
#    'countryCode': 'FI',
#    'type': 'DEPARTURE',
#    'trainStopping': False,
#    'cancelled': False,
#    'scheduledTime': '2026-02-01T07:13:00.000Z',
#    'actualTime': '2026-02-01T07:13:47.000Z',
#    'differenceInMinutes': 1,
#    'causes': [],
#    'commercialTrack': ''},
#   {'stationShortCode': 'JTS',
#    'stationUICCode': 499,
#    'countryCode': 'FI',
#    'type': 'ARRIVAL',
#    'trainStopping': True,
#    'commercialStop': True,
#    'cancelled': False,
#    'scheduledTime': '2026-02-01T07:19:00.000Z',
#    'actualTime': '2026-02-01T07:19:00.000Z',
#    'differenceInMinutes': 0,
#    'causes': [],
#    'commercialTrack': '1'},
#   {'stationShortCode': 'JTS',
#    'stationUICCode': 499,
#    'countryCode': 'FI',
#    'type': 'DEPARTURE',
#    'trainStopping': True,
#    'commercialStop': True,
#    'cancelled': False,
#    'scheduledTime': '2026-02-01T07:20:00.000Z',
#    'actualTime': '2026-02-01T07:20:03.000Z',
#    'differenceInMinutes': 0,
#    'causes': [],
#    'commercialTrack': '1'},
#   {'stationShortCode': 'RAH',
#    'stationUICCode': 501,
#    'countryCode': 'FI',
#    'type': 'ARRIVAL',
#    'trainStopping': False,
#    'cancelled': False,
#    'scheduledTime': '2026-02-01T07:28:00.000Z',
#    'actualTime': '2026-02-01T07:27:10.000Z',
#    'differenceInMinutes': -1,
#    'causes': [],
#    'commercialTrack': ''},
#   {'stationShortCode': 'RAH',
#    'stationUICCode': 501,
#    'countryCode': 'FI',
#    'type': 'DEPARTURE',
#    'trainStopping': False,
#    'cancelled': False,
#    'scheduledTime': '2026-02-01T07:28:00.000Z',
#    'actualTime': '2026-02-01T07:27:10.000Z',
#    'differenceInMinutes': -1,
#    'causes': [],
#    'commercialTrack': ''},
#   {'stationShortCode': 'IMR',
#    'stationUICCode': 603,
#    'countryCode': 'FI',
#    'type': 'ARRIVAL',
#    'trainStopping': True,
#    'commercialStop': True,
#    'cancelled': False,
#    'scheduledTime': '2026-02-01T07:32:00.000Z',
#    'actualTime': '2026-02-01T07:30:33.000Z',
#    'differenceInMinutes': -1,
#    'causes': [],
#    'commercialTrack': '1'},
#   {'stationShortCode': 'IMR',
#    'stationUICCode': 603,
#    'countryCode': 'FI',
#    'type': 'DEPARTURE',
#    'trainStopping': True,
#    'commercialStop': True,
#    'cancelled': False,
#    'scheduledTime': '2026-02-01T07:35:00.000Z',
#    'actualTime': '2026-02-01T07:35:57.000Z',
#    'differenceInMinutes': 1,
#    'causes': [],
#    'commercialTrack': '1'},
#   {'stationShortCode': 'IMT',
#    'stationUICCode': 502,
#    'countryCode': 'FI',
#    'type': 'ARRIVAL',
#    'trainStopping': False,
#    'cancelled': False,
#    'scheduledTime': '2026-02-01T07:38:00.000Z',
#    'actualTime': '2026-02-01T07:38:27.000Z',
#    'differenceInMinutes': 0,
#    'causes': [],
#    'commercialTrack': ''},
#   {'stationShortCode': 'IMT',
#    'stationUICCode': 502,
#    'countryCode': 'FI',
#    'type': 'DEPARTURE',
#    'trainStopping': False,
#    'cancelled': False,
#    'scheduledTime': '2026-02-01T07:38:00.000Z',
#    'actualTime': '2026-02-01T07:38:27.000Z',
#    'differenceInMinutes': 0,
#    'causes': [],
#    'commercialTrack': ''},
#   {'stationShortCode': 'IM',
#    'stationUICCode': 1352,
#    'countryCode': 'FI',
#    'type': 'ARRIVAL',
#    'trainStopping': False,
#    'cancelled': False,
#    'scheduledTime': '2026-02-01T07:41:32.000Z',
#    'estimateSource': 'LIIKE_AUTOMATIC',
#    'differenceInMinutes': 1,
#    'causes': [],
#    'commercialTrack': '',
#    'liveEstimateTime': '2026-02-01T07:42:04.000Z'},
#   {'stationShortCode': 'IM',
#    'stationUICCode': 1352,
#    'countryCode': 'FI',
#    'type': 'DEPARTURE',
#    'trainStopping': False,
#    'cancelled': False,
#    'scheduledTime': '2026-02-01T07:41:32.000Z',
#    'estimateSource': 'LIIKE_AUTOMATIC',
#    'differenceInMinutes': 1,
#    'causes': [],
#    'commercialTrack': '',
#    'liveEstimateTime': '2026-02-01T07:42:04.000Z'},
#   {'stationShortCode': 'RJÄ',
#    'stationUICCode': 506,
#    'countryCode': 'FI',
#    'type': 'ARRIVAL',
#    'trainStopping': False,
#    'cancelled': False,
#    'scheduledTime': '2026-02-01T07:49:00.000Z',
#    'actualTime': '2026-02-01T07:48:55.000Z',
#    'differenceInMinutes': 0,
#    'causes': [],
#    'commercialTrack': ''},
#   {'stationShortCode': 'RJÄ',
#    'stationUICCode': 506,
#    'countryCode': 'FI',
#    'type': 'DEPARTURE',
#    'trainStopping': False,
#    'cancelled': False,
#    'scheduledTime': '2026-02-01T07:49:00.000Z',
#    'actualTime': '2026-02-01T07:48:55.000Z',
#    'differenceInMinutes': 0,
#    'causes': [],
#    'commercialTrack': ''},
#   {'stationShortCode': 'SPL',
#    'stationUICCode': 507,
#    'countryCode': 'FI',
#    'type': 'ARRIVAL',
#    'trainStopping': True,
#    'commercialStop': True,
#    'cancelled': False,
#    'scheduledTime': '2026-02-01T08:01:00.000Z',
#    'actualTime': '2026-02-01T08:00:55.000Z',
#    'differenceInMinutes': 0,
#    'causes': [],
#    'commercialTrack': '2'},
#   {'stationShortCode': 'SPL',
#    'stationUICCode': 507,
#    'countryCode': 'FI',
#    'type': 'DEPARTURE',
#    'trainStopping': True,
#    'commercialStop': True,
#    'cancelled': False,
#    'scheduledTime': '2026-02-01T08:02:00.000Z',
#    'actualTime': '2026-02-01T08:03:18.000Z',
#    'differenceInMinutes': 1,
#    'causes': [],
#    'commercialTrack': '2'},
#   {'stationShortCode': 'KIJ',
#    'stationUICCode': 1123,
#    'countryCode': 'FI',
#    'type': 'ARRIVAL',
#    'trainStopping': False,
#    'cancelled': False,
#    'scheduledTime': '2026-02-01T08:13:03.000Z',
#    'estimateSource': 'LIIKE_AUTOMATIC',
#    'differenceInMinutes': 0,
#    'causes': [],
#    'commercialTrack': '',
#    'liveEstimateTime': '2026-02-01T08:13:03.000Z'},
#   {'stationShortCode': 'KIJ',
#    'stationUICCode': 1123,
#    'countryCode': 'FI',
#    'type': 'DEPARTURE',
#    'trainStopping': False,
#    'cancelled': False,
#    'scheduledTime': '2026-02-01T08:13:03.000Z',
#    'estimateSource': 'LIIKE_AUTOMATIC',
#    'differenceInMinutes': 0,
#    'causes': [],
#    'commercialTrack': '',
#    'liveEstimateTime': '2026-02-01T08:13:03.000Z'},
#   {'stationShortCode': 'PAR',
#    'stationUICCode': 510,
#    'countryCode': 'FI',
#    'type': 'ARRIVAL',
#    'trainStopping': True,
#    'commercialStop': True,
#    'cancelled': False,
#    'scheduledTime': '2026-02-01T08:15:00.000Z',
#    'actualTime': '2026-02-01T08:14:47.000Z',
#    'differenceInMinutes': 0,
#    'causes': [],
#    'commercialTrack': '1'},
#   {'stationShortCode': 'PAR',
#    'stationUICCode': 510,
#    'countryCode': 'FI',
#    'type': 'DEPARTURE',
#    'trainStopping': True,
#    'commercialStop': True,
#    'cancelled': False,
#    'scheduledTime': '2026-02-01T08:18:00.000Z',
#    'actualTime': '2026-02-01T08:19:34.000Z',
#    'differenceInMinutes': 2,
#    'causes': [],
#    'commercialTrack': '1'},
#   {'stationShortCode': 'SR',
#    'stationUICCode': 964,
#    'countryCode': 'FI',
#    'type': 'ARRIVAL',
#    'trainStopping': False,
#    'cancelled': False,
#    'scheduledTime': '2026-02-01T08:28:00.000Z',
#    'actualTime': '2026-02-01T08:28:34.000Z',
#    'differenceInMinutes': 1,
#    'causes': [],
#    'commercialTrack': ''},
#   {'stationShortCode': 'SR',
#    'stationUICCode': 964,
#    'countryCode': 'FI',
#    'type': 'DEPARTURE',
#    'trainStopping': False,
#    'cancelled': False,
#    'scheduledTime': '2026-02-01T08:28:00.000Z',
#    'actualTime': '2026-02-01T08:28:34.000Z',
#    'differenceInMinutes': 1,
#    'causes': [],
#    'commercialTrack': ''},
#   {'stationShortCode': 'POI',
#    'stationUICCode': 965,
#    'countryCode': 'FI',
#    'type': 'ARRIVAL',
#    'trainStopping': False,
#    'cancelled': False,
#    'scheduledTime': '2026-02-01T08:33:33.000Z',
#    'estimateSource': 'LIIKE_AUTOMATIC',
#    'differenceInMinutes': 0,
#    'causes': [],
#    'commercialTrack': '',
#    'liveEstimateTime': '2026-02-01T08:33:33.000Z'},
#   {'stationShortCode': 'POI',
#    'stationUICCode': 965,
#    'countryCode': 'FI',
#    'type': 'DEPARTURE',
#    'trainStopping': False,
#    'cancelled': False,
#    'scheduledTime': '2026-02-01T08:33:33.000Z',
#    'estimateSource': 'LIIKE_AUTOMATIC',
#    'differenceInMinutes': 0,
#    'causes': [],
#    'commercialTrack': '',
#    'liveEstimateTime': '2026-02-01T08:33:33.000Z'},
#   {'stationShortCode': 'KTI',
#    'stationUICCode': 966,
#    'countryCode': 'FI',
#    'type': 'ARRIVAL',
#    'trainStopping': True,
#    'commercialStop': True,
#    'cancelled': False,
#    'scheduledTime': '2026-02-01T08:39:00.000Z',
#    'actualTime': '2026-02-01T08:39:48.000Z',
#    'differenceInMinutes': 1,
#    'causes': [],
#    'commercialTrack': '1'},
#   {'stationShortCode': 'KTI',
#    'stationUICCode': 966,
#    'countryCode': 'FI',
#    'type': 'DEPARTURE',
#    'trainStopping': True,
#    'commercialStop': True,
#    'cancelled': False,
#    'scheduledTime': '2026-02-01T08:40:00.000Z',
#    'actualTime': '2026-02-01T08:41:05.000Z',
#    'differenceInMinutes': 1,
#    'causes': [],
#    'commercialTrack': '1'},
#   {'stationShortCode': 'PUS',
#    'stationUICCode': 919,
#    'countryCode': 'FI',
#    'type': 'ARRIVAL',
#    'trainStopping': False,
#    'cancelled': False,
#    'scheduledTime': '2026-02-01T08:57:00.000Z',
#    'actualTime': '2026-02-01T08:56:29.000Z',
#    'differenceInMinutes': -1,
#    'causes': [],
#    'commercialTrack': ''},
#   {'stationShortCode': 'PUS',
#    'stationUICCode': 919,
#    'countryCode': 'FI',
#    'type': 'DEPARTURE',
#    'trainStopping': False,
#    'cancelled': False,
#    'scheduledTime': '2026-02-01T08:57:00.000Z',
#    'actualTime': '2026-02-01T08:56:29.000Z',
#    'differenceInMinutes': -1,
#    'causes': [],
#    'commercialTrack': ''},
#   {'stationShortCode': 'KIT',
#    'stationUICCode': 453,
#    'countryCode': 'FI',
#    'type': 'ARRIVAL',
#    'trainStopping': True,
#    'commercialStop': True,
#    'cancelled': False,
#    'scheduledTime': '2026-02-01T09:02:00.000Z',
#    'actualTime': '2026-02-01T09:02:01.000Z',
#    'differenceInMinutes': 0,
#    'causes': [],
#    'commercialTrack': '1'},
#   {'stationShortCode': 'KIT',
#    'stationUICCode': 453,
#    'countryCode': 'FI',
#    'type': 'DEPARTURE',
#    'trainStopping': True,
#    'commercialStop': True,
#    'cancelled': False,
#    'scheduledTime': '2026-02-01T09:03:00.000Z',
#    'actualTime': '2026-02-01T09:03:44.000Z',
#    'differenceInMinutes': 1,
#    'causes': [],
#    'commercialTrack': '1'},
#   {'stationShortCode': 'SÄ',
#    'stationUICCode': 918,
#    'countryCode': 'FI',
#    'type': 'ARRIVAL',
#    'trainStopping': False,
#    'cancelled': False,
#    'scheduledTime': '2026-02-01T09:14:00.000Z',
#    'actualTime': '2026-02-01T09:14:40.000Z',
#    'differenceInMinutes': 1,
#    'causes': [],
#    'commercialTrack': ''},
#   {'stationShortCode': 'SÄ',
#    'stationUICCode': 918,
#    'countryCode': 'FI',
#    'type': 'DEPARTURE',
#    'trainStopping': False,
#    'cancelled': False,
#    'scheduledTime': '2026-02-01T09:14:00.000Z',
#    'actualTime': '2026-02-01T09:14:40.000Z',
#    'differenceInMinutes': 1,
#    'causes': [],
#    'commercialTrack': ''},
#   {'stationShortCode': 'TKK',
#    'stationUICCode': 916,
#    'countryCode': 'FI',
#    'type': 'ARRIVAL',
#    'trainStopping': False,
#    'cancelled': False,
#    'scheduledTime': '2026-02-01T09:17:00.000Z',
#    'actualTime': '2026-02-01T09:17:40.000Z',
#    'differenceInMinutes': 1,
#    'causes': [],
#    'commercialTrack': ''},
#   {'stationShortCode': 'TKK',
#    'stationUICCode': 916,
#    'countryCode': 'FI',
#    'type': 'DEPARTURE',
#    'trainStopping': False,
#    'cancelled': False,
#    'scheduledTime': '2026-02-01T09:17:00.000Z',
#    'actualTime': '2026-02-01T09:17:40.000Z',
#    'differenceInMinutes': 1,
#    'causes': [],
#    'commercialTrack': ''},
#   {'stationShortCode': 'HSL',
#    'stationUICCode': 451,
#    'countryCode': 'FI',
#    'type': 'ARRIVAL',
#    'trainStopping': False,
#    'cancelled': False,
#    'scheduledTime': '2026-02-01T09:22:00.000Z',
#    'actualTime': '2026-02-01T09:22:48.000Z',
#    'differenceInMinutes': 1,
#    'causes': [],
#    'commercialTrack': ''},
#   {'stationShortCode': 'HSL',
#    'stationUICCode': 451,
#    'countryCode': 'FI',
#    'type': 'DEPARTURE',
#    'trainStopping': False,
#    'cancelled': False,
#    'scheduledTime': '2026-02-01T09:22:00.000Z',
#    'actualTime': '2026-02-01T09:22:48.000Z',
#    'differenceInMinutes': 1,
#    'causes': [],
#    'commercialTrack': ''},
#   {'stationShortCode': 'NTH',
#    'stationUICCode': 917,
#    'countryCode': 'FI',
#    'type': 'ARRIVAL',
#    'trainStopping': False,
#    'cancelled': False,
#    'scheduledTime': '2026-02-01T09:28:00.000Z',
#    'actualTime': '2026-02-01T09:29:11.000Z',
#    'differenceInMinutes': 1,
#    'causes': [],
#    'commercialTrack': ''},
#   {'stationShortCode': 'NTH',
#    'stationUICCode': 917,
#    'countryCode': 'FI',
#    'type': 'DEPARTURE',
#    'trainStopping': False,
#    'cancelled': False,
#    'scheduledTime': '2026-02-01T09:28:00.000Z',
#    'actualTime': '2026-02-01T09:29:11.000Z',
#    'differenceInMinutes': 1,
#    'causes': [],
#    'commercialTrack': ''},
#   {'stationShortCode': 'KPP',
#    'stationUICCode': 1369,
#    'countryCode': 'FI',
#    'type': 'ARRIVAL',
#    'trainStopping': False,
#    'cancelled': False,
#    'scheduledTime': '2026-02-01T09:33:30.000Z',
#    'actualTime': '2026-02-01T09:32:50.000Z',
#    'differenceInMinutes': -1,
#    'causes': [],
#    'commercialTrack': ''},
#   {'stationShortCode': 'KPP',
#    'stationUICCode': 1369,
#    'countryCode': 'FI',
#    'type': 'DEPARTURE',
#    'trainStopping': False,
#    'cancelled': False,
#    'scheduledTime': '2026-02-01T09:33:30.000Z',
#    'actualTime': '2026-02-01T09:32:50.000Z',
#    'differenceInMinutes': -1,
#    'causes': [],
#    'commercialTrack': ''},
#   {'stationShortCode': 'SUL',
#    'stationUICCode': 1071,
#    'countryCode': 'FI',
#    'type': 'ARRIVAL',
#    'trainStopping': False,
#    'cancelled': False,
#    'scheduledTime': '2026-02-01T09:34:47.000Z',
#    'actualTime': '2026-02-01T09:34:13.000Z',
#    'differenceInMinutes': -1,
#    'causes': [],
#    'commercialTrack': ''},
#   {'stationShortCode': 'SUL',
#    'stationUICCode': 1071,
#    'countryCode': 'FI',
#    'type': 'DEPARTURE',
#    'trainStopping': False,
#    'cancelled': False,
#    'scheduledTime': '2026-02-01T09:34:47.000Z',
#    'actualTime': '2026-02-01T09:34:13.000Z',
#    'differenceInMinutes': -1,
#    'causes': [],
#    'commercialTrack': ''},
#   {'stationShortCode': 'PLT',
#    'stationUICCode': 1070,
#    'countryCode': 'FI',
#    'type': 'ARRIVAL',
#    'trainStopping': False,
#    'cancelled': False,
#    'scheduledTime': '2026-02-01T09:35:27.000Z',
#    'actualTime': '2026-02-01T09:34:53.000Z',
#    'differenceInMinutes': -1,
#    'causes': [],
#    'commercialTrack': ''},
#   {'stationShortCode': 'PLT',
#    'stationUICCode': 1070,
#    'countryCode': 'FI',
#    'type': 'DEPARTURE',
#    'trainStopping': False,
#    'cancelled': False,
#    'scheduledTime': '2026-02-01T09:35:27.000Z',
#    'actualTime': '2026-02-01T09:34:53.000Z',
#    'differenceInMinutes': -1,
#    'causes': [],
#    'commercialTrack': ''},
#   {'stationShortCode': 'JNS',
#    'stationUICCode': 460,
#    'countryCode': 'FI',
#    'type': 'ARRIVAL',
#    'trainStopping': True,
#    'commercialStop': True,
#    'cancelled': False,
#    'scheduledTime': '2026-02-01T09:36:00.000Z',
#    'actualTime': '2026-02-01T09:36:51.000Z',
#    'differenceInMinutes': 1,
#    'causes': [],
#    'commercialTrack': '2'}]}

# %%
trains = pd.json_normalize(json_list,
                           record_path=['timeTableRows'],
                           meta=[
                              'trainNumber', 
                              'departureDate', 
                              'operatorUICCode',
                              'operatorShortCode',
                              'trainType',
                              'trainCategory',
                              'commuterLineID'
                           ]
)

trains = trains.drop(columns = ['stationUICCode', 'countryCode', 'stopSector', 'commercialTrack', 'trainReady.source', 'trainReady.accepted', 'trainReady.timestamp',
                                'estimateSource', 'liveEstimateTime', 'unknownTrack', 'unknownDelay', 'causes'])

trains.head()
# Out:
#   stationShortCode       type  trainStopping commercialStop  cancelled  \
# 0              HKI  DEPARTURE           True           True      False
# 1              PSL    ARRIVAL           True           True      False
# 2              PSL  DEPARTURE           True           True      False
# 3              LOP    ARRIVAL          False            NaN      False
# 4              LOP  DEPARTURE          False            NaN      False
#
#               scheduledTime                actualTime  differenceInMinutes  \
# 0  2026-02-01T04:54:00.000Z  2026-02-01T04:56:35.000Z                  3.0
# 1  2026-02-01T04:59:00.000Z  2026-02-01T05:01:20.000Z                  2.0
# 2  2026-02-01T05:00:00.000Z  2026-02-01T05:02:53.000Z                  3.0
# 3  2026-02-01T05:00:53.000Z                       NaN                  3.0
# 4  2026-02-01T05:00:53.000Z                       NaN                  3.0
#
#   trainNumber departureDate operatorUICCode operatorShortCode trainType  \
# 0           1    2026-02-01              10                vr         S
# 1           1    2026-02-01              10                vr         S
# 2           1    2026-02-01              10                vr         S
# 3           1    2026-02-01              10                vr         S
# 4           1    2026-02-01              10                vr         S
#
#    trainCategory commuterLineID
# 0  Long-distance
# 1  Long-distance
# 2  Long-distance
# 3  Long-distance
# 4  Long-distance

# %%
trains.tail()
# Out:
#         stationShortCode       type  trainStopping commercialStop  cancelled  \
# 1564783              VRJ    ARRIVAL          False            NaN      False
# 1564784              VRJ  DEPARTURE          False            NaN      False
# 1564785              OLK    ARRIVAL          False            NaN      False
# 1564786              OLK  DEPARTURE          False            NaN      False
# 1564787              KÄP    ARRIVAL           True           True      False
#
#                     scheduledTime                actualTime  \
# 1564783  2026-02-22T01:11:27.000Z                       NaN
# 1564784  2026-02-22T01:11:27.000Z                       NaN
# 1564785  2026-02-22T01:11:54.000Z  2026-02-22T01:14:21.000Z
# 1564786  2026-02-22T01:11:54.000Z  2026-02-22T01:14:56.000Z
# 1564787  2026-02-22T01:13:21.000Z  2026-02-22T01:16:49.000Z
#
#          differenceInMinutes trainNumber departureDate operatorUICCode  \
# 1564783                  2.0       76042    2026-02-22            9999
# 1564784                  2.0       76042    2026-02-22            9999
# 1564785                  2.0       76042    2026-02-22            9999
# 1564786                  3.0       76042    2026-02-22            9999
# 1564787                  3.0       76042    2026-02-22            9999
#
#         operatorShortCode trainType      trainCategory commuterLineID
# 1564783             winco       TYO  On-track machines
# 1564784             winco       TYO  On-track machines
# 1564785             winco       TYO  On-track machines
# 1564786             winco       TYO  On-track machines
# 1564787             winco       TYO  On-track machines

# %%
columns = ['departureDate', 'trainNumber', 'trainCategory', 'trainType', 'commuterLineID', 'stationShortCode', 'type', 
           'trainStopping', 'commercialStop', 'scheduledTime', 'actualTime', 'differenceInMinutes', 'operatorUICCode', 'operatorShortCode', 'cancelled']

trains = trains[columns]
trains.head()
# Out:
#   departureDate trainNumber  trainCategory trainType commuterLineID  \
# 0    2026-02-01           1  Long-distance         S
# 1    2026-02-01           1  Long-distance         S
# 2    2026-02-01           1  Long-distance         S
# 3    2026-02-01           1  Long-distance         S
# 4    2026-02-01           1  Long-distance         S
#
#   stationShortCode       type  trainStopping commercialStop  \
# 0              HKI  DEPARTURE           True           True
# 1              PSL    ARRIVAL           True           True
# 2              PSL  DEPARTURE           True           True
# 3              LOP    ARRIVAL          False            NaN
# 4              LOP  DEPARTURE          False            NaN
#
#               scheduledTime                actualTime  differenceInMinutes  \
# 0  2026-02-01T04:54:00.000Z  2026-02-01T04:56:35.000Z                  3.0
# 1  2026-02-01T04:59:00.000Z  2026-02-01T05:01:20.000Z                  2.0
# 2  2026-02-01T05:00:00.000Z  2026-02-01T05:02:53.000Z                  3.0
# 3  2026-02-01T05:00:53.000Z                       NaN                  3.0
# 4  2026-02-01T05:00:53.000Z                       NaN                  3.0
#
#   operatorUICCode operatorShortCode  cancelled
# 0              10                vr      False
# 1              10                vr      False
# 2              10                vr      False
# 3              10                vr      False
# 4              10                vr      False

# %%
print(f'Dataframessa on {trains.shape[0]} riviä ja {trains.shape[1]} saraketta.')
# Out:
# Dataframessa on 1564788 riviä ja 15 saraketta.

# %% [markdown]
# ## Junatiedot .parquet-muotoon

# %%
week_number = first_day_of_previous_week.isocalendar().week
year = first_day_of_previous_week.year
trains.to_parquet(rf'Data\vr_trains_{year}_week_{week_number}.parquet', index=False)
